# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_df = pd.read_csv("./data/weather_forecast_data.csv")
data_df
# Out:
#       Temperature   Humidity  Wind_Speed  Cloud_Cover     Pressure     Rain
# 0       23.720338  89.592641    7.335604    50.501694  1032.378759     rain
# 1       27.879734  46.489704    5.952484     4.990053   992.614190  no rain
# 2       25.069084  83.072843    1.371992    14.855784  1007.231620  no rain
# 3       23.622080  74.367758    7.050551    67.255282   982.632013     rain
# 4       20.591370  96.858822    4.643921    47.676444   980.825142  no rain
# ...           ...        ...         ...          ...          ...      ...
# 2495    21.791602  45.270902   11.807192    55.044682  1017.686181  no rain
# 2496    27.558479  46.481744   10.884915    39.715133  1008.590961  no rain
# 2497    28.108274  43.817178    2.897128    75.842952   999.119187  no rain
# 2498    14.789275  57.908105    2.374717     2.378743  1046.501875  no rain
# 2499    26.554356  97.101517   18.563084    81.357508  1001.729176  no rain
#
# [2500 rows x 6 columns]

# %%
data_df.describe()
# Out:
#        Temperature     Humidity   Wind_Speed  Cloud_Cover     Pressure
# count  2500.000000  2500.000000  2500.000000  2500.000000  2500.000000
# mean     22.581725    64.347094     9.906255    49.658104  1014.312336
# std       7.326996    19.954739     5.780316    29.123104    20.196433
# min      10.001842    30.005071     0.009819     0.015038   980.014486
# 25%      16.359398    47.339815     4.761909    23.900016   996.938630
# 50%      22.536448    63.920797     9.908572    49.488284  1013.433035
# 75%      28.976476    81.561021    14.948408    75.324140  1031.735067
# max      34.995214    99.997481    19.999132    99.997795  1049.985593

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  2500 non-null   float64
#  1   Humidity     2500 non-null   float64
#  2   Wind_Speed   2500 non-null   float64
#  3   Cloud_Cover  2500 non-null   float64
#  4   Pressure     2500 non-null   float64
#  5   Rain         2500 non-null   object
# dtypes: float64(5), object(1)
# memory usage: 117.3+ KB

# %%
sns.barplot(data = data_df, y = 'Humidity',hue = 'Rain')
plt.title("Tương quan giữa độ ẩm và mưa")
# Out:
# Text(0.5, 1.0, 'Tương quan giữa độ ẩm và mưa')

# %%
data_df.groupby('Rain')['Humidity'].mean()
# Out:
# Rain
# no rain    61.455151
# rain       84.480176
# Name: Humidity, dtype: float64

# %%
sns.barplot(data = data_df, y = 'Temperature',hue = 'Rain')
plt.title("Tương quan giữa nhiệt độ và mưa")
# Out:
# Text(0.5, 1.0, 'Tương quan giữa nhiệt độ và mưa')

# %%
sns.barplot(data = data_df, y = 'Wind_Speed',hue = 'Rain')
plt.title("Tương quan giữa sức gió và mưa")
plt.ylim(9,11)
# Out:
# (9.0, 11.0)

# %%
sns.barplot(data = data_df, y = 'Cloud_Cover',hue = 'Rain')
plt.title("Tương quan giữa độ bao phủ mây và mưa")
# Out:
# Text(0.5, 1.0, 'Tương quan giữa độ bao phủ mây và mưa')

# %%
sns.barplot(data = data_df, y = 'Pressure',hue = 'Rain')
plt.title("Tương quan giữa áp suất và mưa")
plt.ylim(1010, 1020)
# Out:
# (1010.0, 1020.0)

# %%
#ap suat va suc gio 
sns.scatterplot(data = data_df, x = 'Pressure', y = 'Wind_Speed', hue = 'Rain')
# Out:
# <Axes: xlabel='Pressure', ylabel='Wind_Speed'>

# %%
sns.scatterplot(data = data_df, x = 'Temperature', y = 'Wind_Speed', hue = 'Rain')
# Out:
# <Axes: xlabel='Temperature', ylabel='Wind_Speed'>

# %%
sns.scatterplot(data = data_df, x = 'Cloud_Cover', y = 'Humidity', hue = 'Rain')
# Out:
# <Axes: xlabel='Cloud_Cover', ylabel='Humidity'>

# %%
sns.scatterplot(data = data_df, x = 'Pressure', y = 'Cloud_Cover', hue = 'Rain')
# Out:
# <Axes: xlabel='Pressure', ylabel='Cloud_Cover'>

# %%
sns.scatterplot(data = data_df, x = 'Humidity', y = 'Cloud_Cover', hue = 'Rain')
# Out:
# <Axes: xlabel='Humidity', ylabel='Cloud_Cover'>

# %%
feature_cols = data_df.columns.tolist()
def display_missing(df, feature_cols):
    n_rows = df.shape[0]
    for col in feature_cols:
        missing_count = df[col].isnull().sum()
        if missing_count>0:
            print(f"Col {col} has {missing_count*100/n_rows:.2f}% missing values.")
        else:
            print(f"Column {col} dont exist missing value")
display_missing(data_df, feature_cols)
# Out:
# Column Temperature dont exist missing value
# Column Humidity dont exist missing value
# Column Wind_Speed dont exist missing value
# Column Cloud_Cover dont exist missing value
# Column Pressure dont exist missing value
# Column Rain dont exist missing value

# %%
train_df = data_df[['Temperature','Humidity','Cloud_Cover','Rain']]

# %%
train_df
# Out:
#       Temperature   Humidity  Cloud_Cover     Rain
# 0       23.720338  89.592641    50.501694     rain
# 1       27.879734  46.489704     4.990053  no rain
# 2       25.069084  83.072843    14.855784  no rain
# 3       23.622080  74.367758    67.255282     rain
# 4       20.591370  96.858822    47.676444  no rain
# ...           ...        ...          ...      ...
# 2495    21.791602  45.270902    55.044682  no rain
# 2496    27.558479  46.481744    39.715133  no rain
# 2497    28.108274  43.817178    75.842952  no rain
# 2498    14.789275  57.908105     2.378743  no rain
# 2499    26.554356  97.101517    81.357508  no rain
#
# [2500 rows x 4 columns]

# %%
data_df['Rain'] = data_df['Rain'].astype('category')

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  2500 non-null   float64
#  1   Humidity     2500 non-null   float64
#  2   Cloud_Cover  2500 non-null   float64
#  3   Rain         2500 non-null   category
# dtypes: category(1), float64(3)
# memory usage: 61.3 KB
